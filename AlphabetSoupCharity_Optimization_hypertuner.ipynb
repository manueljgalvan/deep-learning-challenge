# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Load the dataset
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")

# Preprocessing (same as before)
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# Binning APPLICATION_TYPE
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
threshold = 500
application_types_to_replace = application_type_counts[application_type_counts < threshold].index
application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(application_types_to_replace, 'Other')

# Binning CLASSIFICATION
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 300].index)
application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(classifications_to_replace, "Other")

# Convert categorical data to numeric
numeric_app_df = pd.get_dummies(application_df)

# Split data
y = numeric_app_df["IS_SUCCESSFUL"]
X = numeric_app_df.drop(["IS_SUCCESSFUL"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Scale data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Define the model (modified for optimization)
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80  # Increased nodes
hidden_nodes_layer2 = 30 # Increased nodes
hidden_nodes_layer3 = 10 # Added another layer

nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu")) #Added layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Compile the model with different optimizer and learning rate
nn.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# Early stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Train the model with increased epochs and validation data
fit_model = nn.fit(X_train_scaled, y_train, epochs=20, validation_split=0.15, callbacks=[early_stopping]) #Added validation split and early stopping

# Evaluate the model
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/20
# c:\Users\galva\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 848us/step - accuracy: 0.6983 - loss: 0.5949 - val_accuracy: 0.7261 - val_loss: 0.5636
# Epoch 2/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - accuracy: 0.7326 - loss: 0.5511 - val_accuracy: 0.7253 - val_loss: 0.5590
# Epoch 3/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - accuracy: 0.7334 - loss: 0.5485 - val_accuracy: 0.7227 - val_loss: 0.5609
# Epoch 4/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.7344 - loss: 0.5499 - val_accuracy: 0.7232 - val_loss: 0.5592
# Epoch 5/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.7353 - loss: 0.5431 - val_accuracy: 0.7248 - val_loss: 0.5595
# Epoch 6/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - accuracy: 0.7383 - loss: 0.5447 - val_accuracy: 0.7232 - val_loss: 0.5589
# Epoch 7/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.7349 - loss: 0.5449 - val_accuracy: 0.7248 - val_loss: 0.5570
# Epoch 8/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 658us/step - accuracy: 0.7432 - loss: 0.5381 - val_accuracy: 0.7240 - val_loss: 0.5595
# Epoch 9/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - accuracy: 0.7359 - loss: 0.5427 - val_accuracy: 0.7222 - val_loss: 0.5612
# Epoch 10/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - accuracy: 0.7365 - loss: 0.5458 - val_accuracy: 0.7204 - val_loss: 0.5624
# Epoch 11/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - accuracy: 0.7367 - loss: 0.5466 - val_accuracy: 0.7261 - val_loss: 0.5579
# Epoch 12/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - accuracy: 0.7404 - loss: 0.5406 - val_accuracy: 0.7212 - val_loss: 0.5571
# Epoch 13/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step - accuracy: 0.7382 - loss: 0.5435 - val_accuracy: 0.7222 - val_loss: 0.5597
# Epoch 14/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - accuracy: 0.7368 - loss: 0.5430 - val_accuracy: 0.7230 - val_loss: 0.5603
# Epoch 15/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.7376 - loss: 0.5413 - val_accuracy: 0.7199 - val_loss: 0.5597
# Epoch 16/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - accuracy: 0.7399 - loss: 0.5396 - val_accuracy: 0.7178 - val_loss: 0.5606
# Epoch 17/20
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 710us/step - accuracy: 0.7345 - loss: 0.5435 - val_accuracy: 0.7225 - val_loss: 0.5635
# 268/268 - 0s - 475us/step - accuracy: 0.7254 - loss: 0.5522
# Loss: 0.552157461643219, Accuracy: 0.7253644466400146

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras_tuner as kt

# Load the dataset
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")

# Preprocessing (same as before)
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# Binning APPLICATION_TYPE
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
threshold = 500
application_types_to_replace = application_type_counts[application_type_counts < threshold].index
application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(application_types_to_replace, 'Other')

# Binning CLASSIFICATION
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = list(classification_counts[classification_counts < 300].index)
application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(classifications_to_replace, "Other")

# Convert categorical data to numeric
numeric_app_df = pd.get_dummies(application_df)

# Split data
y = numeric_app_df["IS_SUCCESSFUL"]
X = numeric_app_df.drop(["IS_SUCCESSFUL"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Scale data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

def build_model(hp):
    number_input_features = len(X_train_scaled[0])
    nn_model = tf.keras.models.Sequential()

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    nn_model.add(tf.keras.layers.Dense(units=hp_units1, activation='relu', input_dim=number_input_features))


    # Add another dense layer
    hp_units2 = hp.Int('units2', min_value=32, max_value=512, step=32)
    nn_model.add(tf.keras.layers.Dense(units=hp_units2, activation='relu'))

        # Add another dense layer
    hp_units2 = hp.Int('units3', min_value=32, max_value=512, step=32)
    nn_model.add(tf.keras.layers.Dense(units=hp_units2, activation='relu'))

    # Add another dense layer
    hp_units2 = hp.Int('units4', min_value=32, max_value=512, step=32)
    nn_model.add(tf.keras.layers.Dense(units=hp_units2, activation='relu'))

    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    nn_model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate), metrics=["accuracy"])
    return nn_model

tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=20,
    factor=3,
    directory='my_dir',
    project_name='intro_to_kt'
)

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(X_train_scaled,y_train,epochs=20,validation_split=0.15,callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=3)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units1')}, and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")

# Evaluate the hypermodel
model = tuner.hypermodel.build(best_hps)
history = model.fit(X_train_scaled, y_train, epochs=50, validation_split=0.15)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))

hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(X_train_scaled, y_train, epochs=best_epoch, validation_split=0.15)

eval_result = hypermodel.evaluate(X_test_scaled, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# Reloading Tuner from my_dir\intro_to_kt\tuner0.json
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 64, and the optimal learning rate for the optimizer
# is 0.001.
# c:\Users\galva\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 901us/step - accuracy: 0.6993 - loss: 0.5897 - val_accuracy: 0.7196 - val_loss: 0.5621
# Epoch 2/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.7269 - loss: 0.5566 - val_accuracy: 0.7201 - val_loss: 0.5659
# Epoch 3/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 739us/step - accuracy: 0.7416 - loss: 0.5414 - val_accuracy: 0.7209 - val_loss: 0.5716
# Epoch 4/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - accuracy: 0.7362 - loss: 0.5488 - val_accuracy: 0.7207 - val_loss: 0.5618
# Epoch 5/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step - accuracy: 0.7349 - loss: 0.5458 - val_accuracy: 0.7227 - val_loss: 0.5558
# Epoch 6/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - accuracy: 0.7361 - loss: 0.5429 - val_accuracy: 0.7225 - val_loss: 0.5608
# Epoch 7/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 711us/step - accuracy: 0.7326 - loss: 0.5494 - val_accuracy: 0.7219 - val_loss: 0.5567
# Epoch 8/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/
50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 736us/step - accuracy: 0.7428 - loss: 0.5364 - val_accuracy: 0.7240 - val_loss: 0.5644
# Epoch 35/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 722us/step - accuracy: 0.7409 - loss: 0.5360 - val_accuracy: 0.7232 - val_loss: 0.5635
# Epoch 36/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - accuracy: 0.7442 - loss: 0.5345 - val_accuracy: 0.7214 - val_loss: 0.5632
# Epoch 37/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 712us/step - accuracy: 0.7398 - loss: 0.5358 - val_accuracy: 0.7240 - val_loss: 0.5652
# Epoch 38/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step - accuracy: 0.7480 - loss: 0.5286 - val_accuracy: 0.7225 - val_loss: 0.5674
# Epoch 39/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step - accuracy: 0.7396 - loss: 0.5392 - val_accuracy: 0.7212 - val_loss: 0.5656
# Epoch 40/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 708us/step - accuracy: 0.7410 - loss: 0.5328 - val_accuracy: 0.7235 - val_loss: 0.5635
# Epoch 41/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.7421 - loss: 0.5319 - val_accuracy: 0.7248 - val_loss: 0.5656
# Epoch 42/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - accuracy: 0.7433 - loss: 0.5359 - val_accuracy: 0.7219 - val_loss: 0.5662
# Epoch 43/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step - accuracy: 0.7400 - loss: 0.5366 - val_accuracy: 0.7209 - val_loss: 0.5671
# Epoch 44/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 766us/step - accuracy: 0.7399 - loss: 0.5371 - val_accuracy: 0.7227 - val_loss: 0.5662
# Epoch 45/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 852us/step - accuracy: 0.7447 - loss: 0.5307 - val_accuracy: 0.7214 - val_loss: 0.5679
# Epoch 46/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 823us/step - accuracy: 0.7444 - loss: 0.5311 - val_accuracy: 0.7230 - val_loss: 0.5691
# Epoch 47/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 810us/step - accuracy: 0.7397 - loss: 0.5381 - val_accuracy: 0.7238 - val_loss: 0.5681
# Epoch 48/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 876us/step - accuracy: 0.7396 - loss: 0.5377 - val_accuracy: 0.7240 - val_loss: 0.5678
# Epoch 49/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 796us/step - accuracy: 0.7465 - loss: 0.5319 - val_accuracy: 0.7243 - val_loss: 0.5685
# Epoch 50/50
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.7410 - loss: 0.5334 - val_accuracy: 0.7232 - val_loss: 0.5711
# Best epoch: 33
# Epoch 1/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7134 - loss: 0.5855 - val_accuracy: 0.7219 - val_loss: 0.5673
# Epoch 2/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 759us/step - accuracy: 0.7322 - loss: 0.5544 - val_accuracy: 0.7204 - val_loss: 0.5597
# Epoch 3/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 804us/step - accuracy: 0.7285 - loss: 0.5531 - val_accuracy: 0.7144 - val_loss: 0.5717
# Epoch 4/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 944us/step - accuracy: 0.7367 - loss: 0.5486 - val_accuracy: 0.7245 - val_loss: 0.5620
# Epoch 5/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.7332 - loss: 0.5498 - val_accuracy: 0.7188 - val_loss: 0.5635
# Epoch 6/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.7361 - loss: 0.5462 - val_accuracy: 0.7230 - val_loss: 0.5587
# Epoch 7/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.7384 - loss: 0.5451 - val_accuracy: 0.7269 - val_loss: 0.5561
# Epoch 8/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 793us/step - accuracy: 0.7368 - loss: 0.5425 - val_accuracy: 0.7196 - val_loss: 0.5567
# Epoch 9/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 752us/step - accuracy: 0.7336 - loss: 0.5459 - val_accuracy: 0.7207 - val_loss: 0.5574
# Epoch 10/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - accuracy: 0.7397 - loss: 0.5405 - val_accuracy: 0.7212 - val_loss: 0.5610
# Epoch 11/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.7430 - loss: 0.5432 - val_accuracy: 0.7222 - val_loss: 0.5639
# Epoch 12/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.7381 - loss: 0.5434 - val_accuracy: 0.7258 - val_loss: 0.5555
# Epoch 13/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.7402 - loss: 0.5426 - val_accuracy: 0.7245 - val_loss: 0.5581
# Epoch 14/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 765us/step - accuracy: 0.7438 - loss: 0.5360 - val_accuracy: 0.7217 - val_loss: 0.5595
# Epoch 15/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - accuracy: 0.7425 - loss: 0.5381 - val_accuracy: 0.7235 - val_loss: 0.5604
# Epoch 16/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step - accuracy: 0.7402 - loss: 0.5396 - val_accuracy: 0.7256 - val_loss: 0.5566
# Epoch 17/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - accuracy: 0.7406 - loss: 0.5396 - val_accuracy: 0.7251 - val_loss: 0.5575
# Epoch 18/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 728us/step - accuracy: 0.7391 - loss: 0.5403 - val_accuracy: 0.7230 - val_loss: 0.5558
# Epoch 19/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step - accuracy: 0.7409 - loss: 0.5367 - val_accuracy: 0.7201 - val_loss: 0.5586
# Epoch 20/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - accuracy: 0.7378 - loss: 0.5410 - val_accuracy: 0.7232 - val_loss: 0.5617
# Epoch 21/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.7373 - loss: 0.5386 - val_accuracy: 0.7256 - val_loss: 0.5590
# Epoch 22/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step - accuracy: 0.7399 - loss: 0.5404 - val_accuracy: 0.7248 - val_loss: 0.5620
# Epoch 23/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - accuracy: 0.7388 - loss: 0.5405 - val_accuracy: 0.7235 - val_loss: 0.5576
# Epoch 24/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 730us/step - accuracy: 0.7375 - loss: 0.5396 - val_accuracy: 0.7248 - val_loss: 0.5598
# Epoch 25/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 733us/step - accuracy: 0.7382 - loss: 0.5384 - val_accuracy: 0.7248 - val_loss: 0.5587
# Epoch 26/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 734us/step - accuracy: 0.7393 - loss: 0.5398 - val_accuracy: 0.7251 - val_loss: 0.5580
# Epoch 27/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 754us/step - accuracy: 0.7397 - loss: 0.5400 - val_accuracy: 0.7217 - val_loss: 0.5614
# Epoch 28/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.7402 - loss: 0.5371 - val_accuracy: 0.7222 - val_loss: 0.5596
# Epoch 29/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.7400 - loss: 0.5350 - val_accuracy: 0.7222 - val_loss: 0.5602
# Epoch 30/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - accuracy: 0.7417 - loss: 0.5331 - val_accuracy: 0.7248 - val_loss: 0.5620
# Epoch 31/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - accuracy: 0.7359 - loss: 0.5413 - val_accuracy: 0.7240 - val_loss: 0.5660
# Epoch 32/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - accuracy: 0.7435 - loss: 0.5337 - val_accuracy: 0.7253 - val_loss: 0.5615
# Epoch 33/33
# 684/684 ━━━━━━━━━━━━━━━━━━━━ 1s 794us/step - accuracy: 0.7452 - loss: 0.5302 - val_accuracy: 0.7245 - val_loss: 0.5617
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - accuracy: 0.7274 - loss: 0.5484
# [test loss, test accuracy]: [0.554561972618103, 0.7254810333251953]

# %%
# Save the model (optional)
nn.save('Models/AlphabetSoupCharity_optimized_hypertuning.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
